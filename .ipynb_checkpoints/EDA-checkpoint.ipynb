# %%
import pandas as pd
import numpy as np
import seaborn as sns
import calendar
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
store = pd.read_csv("store.csv")
df = pd.read_csv("train.csv", low_memory=False)

# %%
print('sample store data')
store.head()
# Out:
# sample store data
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
print('sample sales data')
df.head()
# Out:
# sample sales data
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      1          4  2015-07-30   5020        546     1      1            0
# 2      1          3  2015-07-29   4782        523     1      1            0
# 3      1          2  2015-07-28   5011        560     1      1            0
# 4      1          1  2015-07-27   6102        612     1      1            0
#
#    SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0              1         c          a               1270.0
# 1              1         c          a               1270.0
# 2              1         c          a               1270.0
# 3              1         c          a               1270.0
# 4              1         c          a               1270.0
#
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                        9.0                    2008.0       0
# 1                        9.0                    2008.0       0
# 2                        9.0                    2008.0       0
# 3                        9.0                    2008.0       0
# 4                        9.0                    2008.0       0
#
#    Promo2SinceWeek  Promo2SinceYear PromoInterval
# 0              NaN              NaN           NaN
# 1              NaN              NaN           NaN
# 2              NaN              NaN           NaN
# 3              NaN              NaN           NaN
# 4              NaN              NaN           NaN

# %%
print ("training data", df.shape)
print ("Stores data", store.shape)
# Out:
# training data (1017209, 27)
# Stores data (1115, 10)

# %% [markdown]
# ### Data Merge

# %%
df = pd.merge(df, store, on='Store') #merge data for analysis
print ("List of columns -", df.columns)
df['Open'] = df['Open'].apply(lambda x: 0 if np.isnan(x) else x) #get rid of NaN values if store is 'closed'
# Out:
# List of columns - Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType_x', 'Assortment_x',
#        'CompetitionDistance_x', 'CompetitionOpenSinceMonth_x',
#        'CompetitionOpenSinceYear_x', 'Promo2_x', 'Promo2SinceWeek_x',
#        'Promo2SinceYear_x', 'PromoInterval_x', 'StoreType_y', 'Assortment_y',
#        'CompetitionDistance_y', 'CompetitionOpenSinceMonth_y',
#        'CompetitionOpenSinceYear_y', 'Promo2_y', 'Promo2SinceWeek_y',
#        'Promo2SinceYear_y', 'PromoInterval_y'],
#       dtype='object')

# %% [markdown]
# ### Data Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1017209 entries, 0 to 1017208
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   Store                        1017209 non-null  int64
#  1   DayOfWeek                    1017209 non-null  int64
#  2   Date                         1017209 non-null  object
#  3   Sales                        1017209 non-null  int64
#  4   Customers                    1017209 non-null  int64
#  5   Open                         1017209 non-null  int64
#  6   Promo                        1017209 non-null  int64
#  7   StateHoliday                 1017209 non-null  object
#  8   SchoolHoliday                1017209 non-null  int64
#  9   StoreType_x                  1017209 non-null  object
#  10  Assortment_x                 1017209 non-null  object
#  11  CompetitionDistance_x        1014567 non-null  float64
#  12  CompetitionOpenSinceMonth_x  693861 non-null   float64
#  13  CompetitionOpenSinceYear_x   693861 non-null   float64
#  14  Promo2_x                     1017209 non-null  int64
#  15  Promo2SinceWeek_x            509178 non-null   float64
#  16  Promo2SinceYear_x            509178 non-null   float64
#  17  PromoInterval_x              509178 non-null   object
#  18  StoreType_y                  1017209 non-null  object
#  19  Assortment_y                 1017209 non-null  object
#  20  CompetitionDistance_y        1014567 non-null  float64
#  21  CompetitionOpenSinceMonth_y  693861 non-null   float64
#  22  CompetitionOpenSinceYear_y   693861 non-null   float64
#  23  Promo2_y                     1017209 non-null  int64
#  24  Promo2SinceWeek_y            509178 non-null   float64
#  25  Promo2SinceYear_y            509178 non-null   float64
#  26  PromoInterval_y              509178 non-null   object
# dtypes: float64(10), int64(9), object(8)
# memory usage: 217.3+ MB

# %%
df.describe()
# Out:
#               Store     DayOfWeek         Sales     Customers          Open  \
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   5.584297e+02  3.998341e+00  5.773819e+03  6.331459e+02  8.301067e-01
# std    3.219087e+02  1.997391e+00  3.849926e+03  4.644117e+02  3.755392e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00  3.727000e+03  4.050000e+02  1.000000e+00
# 50%    5.580000e+02  4.000000e+00  5.744000e+03  6.090000e+02  1.000000e+00
# 75%    8.380000e+02  6.000000e+00  7.856000e+03  8.370000e+02  1.000000e+00
# max    1.115000e+03  7.000000e+00  4.155100e+04  7.388000e+03  1.000000e+00
#
#               Promo  SchoolHoliday  CompetitionDistance_x  \
# count  1.017209e+06   1.017209e+06           1.014567e+06
# mean   3.815145e-01   1.786467e-01           5.430086e+03
# std    4.857586e-01   3.830564e-01           7.715324e+03
# min    0.000000e+00   0.000000e+00           2.000000e+01
# 25%    0.000000e+00   0.000000e+00           7.100000e+02
# 50%    0.000000e+00   0.000000e+00           2.330000e+03
# 75%    1.000000e+00   0.000000e+00           6.890000e+03
# max    1.000000e+00   1.000000e+00           7.586000e+04
#
#        CompetitionOpenSinceMonth_x  CompetitionOpenSinceYear_x      Promo2_x  \
# count                693861.000000               693861.000000  1.017209e+06
# mean                      7.222866                 2008.690228  5.005638e-01
# std                       3.211832                    5.992644  4.999999e-01
# min                       1.000000                 1900.000000  0.000000e+00
# 25%                       4.000000                 2006.000000  0.000000e+00
# 50%                       8.000000                 2010.000000  1.000000e+00
# 75%                      10.000000                 2013.000000  1.000000e+00
# max                      12.000000                 2015.000000  1.000000e+00
#
#        Promo2SinceWeek_x  Promo2SinceYear_x  CompetitionDistance_y  \
# count      509178.000000      509178.000000           1.014567e+06
# mean           23.269093        2011.752774           5.430086e+03
# std            14.095973           1.662870           7.715324e+03
# min             1.000000        2009.000000           2.000000e+01
# 25%            13.000000        2011.000000           7.100000e+02
# 50%            22.000000        2012.000000           2.330000e+03
# 75%            37.000000        2013.000000           6.890000e+03
# max            50.000000        2015.000000           7.586000e+04
#
#        CompetitionOpenSinceMonth_y  CompetitionOpenSinceYear_y      Promo2_y  \
# count                693861.000000               693861.000000  1.017209e+06
# mean                      7.222866                 2008.690228  5.005638e-01
# std                       3.211832                    5.992644  4.999999e-01
# min                       1.000000                 1900.000000  0.000000e+00
# 25%                       4.000000                 2006.000000  0.000000e+00
# 50%                       8.000000                 2010.000000  1.000000e+00
# 75%                      10.000000                 2013.000000  1.000000e+00
# max                      12.000000                 2015.000000  1.000000e+00
#
#        Promo2SinceWeek_y  Promo2SinceYear_y
# count      509178.000000      509178.000000
# mean           23.269093        2011.752774
# std            14.095973           1.662870
# min             1.000000        2009.000000
# 25%            13.000000        2011.000000
# 50%            22.000000        2012.000000
# 75%            37.000000        2013.000000
# max            50.000000        2015.000000

# %%
df['Open'].value_counts()
# Out:
# 1    844392
# 0    172817
# Name: Open, dtype: int64

# %%
#Date time exploration of the data set to add additonal features interms of Day, Month, Year, MonthYear
def date_change(df):
    df['Month'] = df['Date'].apply(lambda x : int(str(x)[5:7]))
    df['Year'] = df['Date'].apply(lambda x : int(str(x)[:4]))
    df['MonthYear'] =df['Date'].apply(lambda x : (str(x)[:7]))
    df['date_int'] = df['Date'].apply(lambda x : (str(x)[8:10]))
    df['date_int'] = df['date_int'].astype(str).astype(int)
    df = df.drop('Date', axis=1)
    return df
df_1 = date_change(df)

# %% [markdown]
# ### Data Visualization

# %%
#a better way to get more details, timeline view of mean of each day of the week-
day = df_1[(df_1['Open']!=0)]
sales_per_day = day.groupby('DayOfWeek')['Sales'].mean()
cust_per_day = day.groupby('DayOfWeek')['Customers'].mean()
#Subplots mapping
fig, (axis1) = plt.subplots(1,1, sharex=True, figsize=(10,5))
# plot mean sales
ax1 = sales_per_day.plot(legend=True, ax=axis1, marker='x',title="Fig. 1, Mean sales of each day of the week")
ax1.set_xticks(sales_day.index)
tmp = ax1.set_xticklabels(sales_day.index.tolist(), rotation=90)
# overlay customer data
cust_per_day.plot(legend=True, ax=axis1, marker='o', secondary_y=True)
# Out:
# <Axes: >

# %%
#a better way to get more details, timeline view of medians of each day of the week-
day = df_1[(df_1['Open']!=0)]
sales_per_day = day.groupby('DayOfWeek')['Sales'].median()
cust_per_day = day.groupby('DayOfWeek')['Customers'].median()
#
fig, (axis1) = plt.subplots(1,1, sharex=True, figsize=(10,5))
# plot median sales
ax1 = sales_per_day.plot(legend=True, ax=axis1, marker='o',title="Fig. 1, Median sales of each day of the week")
ax1.set_xticks(sales_day.index)
tmp = ax1.set_xticklabels(sales_day.index.tolist(), rotation=90)
# overlay customer data
cust_per_day.plot(legend=True, ax=axis1, marker='x', secondary_y=True)
# Out:
# <Axes: >

# %%
day = df_1[(df_1['Open']!=0)]
sales_per_day = day.groupby('date_int')['Sales'].median()
cust_per_day = day.groupby('date_int')['Customers'].median()
#
fig, (axis1) = plt.subplots(1,1, sharex=True, figsize=(10,5))
# plot median sales
ax1 = sales_per_day.plot(legend=True, ax=axis1, marker='o',title="Fig. 2: Sales vs Dates")
ax1.set_xticks(sales_day.index)
#ax1.set_yticks(date_int)
tmp = ax1.set_xticklabels(sales_day.index.tolist(), rotation=90)
# overlay customer data
cust_per_day.plot(legend=True, ax=axis1, marker='x', secondary_y=True)
# Out:
# <Axes: >

# %%
# select all stores that were open
subs = df_1[df_1['Open']!=0]
# groupby Year and Month
selected_sales = subs.groupby(['Year', 'Month'])['Sales'].mean()
selected_cust = subs.groupby(['Year', 'Month'])['Customers'].mean()
# plot
fig, (axis1) = plt.subplots(1,1, figsize=(10,7))
selected_sales.unstack().T.plot(ax=axis1)
tmp = axis1.set_title("Fig. 3: Yearly Sales")
tmp = axis1.set_ylabel("Sales")
tmp = axis1.set_xticks(range(0,13))
tmp = axis1.set_xticklabels(calendar.month_abbr)

# %%
# median sales
median_sales = df_1.groupby('MonthYear')['Sales'].median()
pct_median_change = df_1.groupby('MonthYear')['Sales'].median().pct_change()
# median customers
median_cust = df_1.groupby('MonthYear')['Customers'].median()
pct_median_custchange = df_1.groupby('MonthYear')['Customers'].median().pct_change()

fig, (axis1, axis2) = plt.subplots(2, 1, sharex=True, figsize=(15,15))
# plot median sales
ax1 = median_sales.plot(legend=True, ax=axis1, marker='o',title="Fig. 4a: Monthly changes in Sales/Customers")
ax1.set_xticks(range(len(median_sales)))
ax1.set_xticklabels(median_sales.index.tolist(), rotation=90)
# plot pct change
ax2 = pct_median_change.plot(legend=True, ax=axis2, marker='o',rot=90, title="Fig. 4b: Percent Change")
# overlay customer data
median_cust.plot(legend=True, ax=axis1, marker='x', secondary_y=True)
pct_median_custchange.plot(legend=True, ax=axis2, marker='x', rot=90, secondary_y=True)
# Out:
# <Axes: >

# %%
fig, (axis3) = plt.subplots(1,1, sharex=True, figsize=(10,5))
# stateholiday overlay
# StateHoliday has a mixture of "O", 0 and "0", replace these with "O"
df_1.StateHoliday.replace(["O",0,"0"],['O','O','O'], inplace=True)
ax3 = sns.countplot(x='MonthYear', hue='StateHoliday', data=df_1[df_1['StateHoliday']!='O'], palette='husl', ax=axis3)
tmp = ax3.set_xticklabels(ax3.get_xticklabels(), rotation=90)
tmp = ax3.set_title('Fig. 5: State Holidays')

# %%
fig, (axis4) = plt.subplots(1,1, sharex=True, figsize=(10,5))
ax4 = sns.countplot(x='MonthYear', hue='SchoolHoliday', data=df_1[df_1['SchoolHoliday']!=0], palette='husl', ax=axis4)
subs = df_1[df_1['SchoolHoliday']!=0]
#cntchange = subs.groupby('MonthYear')['SchoolHoliday'].count().pct_change()
#cntchange.plot(ax=axis4, marker='x', secondary_y=True)
tmp = ax4.set_xticklabels(ax4.get_xticklabels(), rotation=90)
tmp = ax4.set_title('Fig.6: School Holidays and Percentage Change in School Holidays')

# %%
fig, (axis5) = plt.subplots(1,1, sharex=True, figsize=(10,5))
#promotions overlay
ax5 = sns.countplot(x='MonthYear', hue='Promo', data=df_1[df_1["Promo"]!=0], palette='husl', ax=axis5)
subs = df_1[df_1['Promo']!=0]
cntchange = subs.groupby('MonthYear')['Promo'].count().pct_change()
cntchange.plot(ax=axis5, marker='x', secondary_y=True)
tmp = ax5.set_xticklabels(ax5.get_xticklabels(), rotation=90)
tmp = ax5.set_title('Fig. 7: Promotions and Percentage Change in Promotions')
